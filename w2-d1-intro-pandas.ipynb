# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.random((3,3)))
display(df)
# Out:
#           0         1         2
# 0  0.521646  0.221352  0.576678
# 1  0.118087  0.274825  0.685723
# 2  0.382574  0.630121  0.449689

# %%
df = pd.DataFrame(np.random.random((3,3)), columns=["A","B","C"])
df
# Out:
#           A         B         C
# 0  0.034971  0.104174  0.165347
# 1  0.421070  0.026575  0.007209
# 2  0.234803  0.950165  0.011836

# %%
b = df["A"]
print(type(df),type(b))
print(b)
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.series.Series'>
# 0    0.034971
# 1    0.421070
# 2    0.234803
# Name: A, dtype: float64

# %%
df[["A","C"]]
# Out:
#           A         C
# 0  0.034971  0.165347
# 1  0.421070  0.007209
# 2  0.234803  0.011836

# %%
df["E"] = df["A"] + df["C"]
df
# Out:
#           A         B         C         E
# 0  0.034971  0.104174  0.165347  0.200317
# 1  0.421070  0.026575  0.007209  0.428279
# 2  0.234803  0.950165  0.011836  0.246639

# %%
df = pd.DataFrame([0,1,2,3,4])
display(df)
df.columns = ["A"]
display(df)
# Out:
#    0
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4
#    A
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %%
df = pd.DataFrame([{
    "name":"Pension Loli",
    "stars":4
},{
    "name":"Ritz",
    "stars":5
},
{
    "name":"Gran Legazpi",
    "stars":3
},
{
    "name":"NH Random",
    "stars":4
},
{
    "name":"NH Random",
    "stars":4
}])

# %%
# convierte una serie en una numpy array
m = df["name"].values
print(m, type(m))

# convertir en una lista de python una numpy array
m = df["name"].values.tolist()
print(m, type(m))

# Convertir el indice de la serie en una lista
m = df["name"].index.tolist()
print(m, type(m))
# Out:
# ['Pension Loli' 'Ritz' 'Gran Legazpi' 'NH Random'] <class 'numpy.ndarray'>
# ['Pension Loli', 'Ritz', 'Gran Legazpi', 'NH Random'] <class 'list'>
# [0, 1, 2, 3] <class 'list'>

# %%
tas = pd.DataFrame({
    "TAs": ["Felipe","Clara","Blanca","Fran"],
    "repr": ["🙋🏻‍♀️","💁🏼‍♀️","💁🏼‍♀️", "👨🏼‍💻"]
})
a = tas["repr"].values.tolist()
a.reverse()
print(a)
tas["mix"] = tas["TAs"] + a
tas
# Out:
# ['👨🏼\u200d💻', '💁🏼\u200d♀️', '💁🏼\u200d♀️', '🙋🏻\u200d♀️']
#       TAs   repr          mix
# 0  Felipe  🙋🏻‍♀️   Felipe👨🏼‍💻
# 1   Clara  💁🏼‍♀️   Clara💁🏼‍♀️
# 2  Blanca  💁🏼‍♀️  Blanca💁🏼‍♀️
# 3    Fran   👨🏼‍💻    Fran🙋🏻‍♀️

# %%
m = [a+b for a,b in zip(["A","B","C"], ["Q","M","P"])]
list(m)
# Out:
# ['AQ', 'BM', 'CP']

# %%
df = pd.read_csv("data/alumnos.csv")
df
# Out:
#   Nombre  Edad  Peso
# 0   Pepe    10    50
# 1   Juan    20    50
# 2   Luis    25    50
# 3   Fran    15    50

# %%
df.sum(axis=1)
# Out:
# 0    60
# 1    70
# 2    75
# 3    65
# dtype: int64

# %%
df.dtypes
# Out:
# Nombre    object
# Edad       int64
# Peso       int64
# dtype: object

# %%
df["Edad"] = df["Edad"].astype(str)
df["Peso"] = df["Peso"].astype(str)

df.dtypes
# Out:
# Nombre    object
# Edad      object
# Peso      object
# dtype: object

# %%
df.sum(axis=1,numeric_only=False)
# Out:
# 0    Pepe1050
# 1    Juan2050
# 2    Luis2550
# 3    Fran1550
# dtype: object

# %%
df = pd.read_csv("data/pokemon.csv")
b = pd.concat([df[0:3],df[6:9]])
b
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False

# %%
np.prod(df.shape)
# Out:
# 10400

# %%
b.iloc[0:4]
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
# 6  6  Charizard   Fire  Flying    534  78      84       78      109       85
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 6    100           1      False

# %%
b.loc[0:4]
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
for col in ["HP","Attack","Defense"]:
    print(col ,df[col].sum())
# Out:
# HP 55407
# Attack 63201
# Defense 59074

# %%
df.sum(numeric_only=True)
# Out:
# #             290251.0
# Total         348082.0
# HP             55407.0
# Attack         63201.0
# Defense        59074.0
# Sp. Atk        58256.0
# Sp. Def        57522.0
# Speed          54622.0
# Generation      2659.0
# Legendary         65.0
# dtype: float64

# %%
df.T.reset_index(drop=True)
# Out:
#           0        1         2                      3           4    \
# 0           1        2         3                      3           4
# 1   Bulbasaur  Ivysaur  Venusaur  VenusaurMega Venusaur  Charmander
# 2       Grass    Grass     Grass                  Grass        Fire
# 3      Poison   Poison    Poison                 Poison         NaN
# 4         318      405       525                    625         309
# 5          45       60        80                     80          39
# 6          49       62        82                    100          52
# 7          49       63        83                    123          43
# 8          65       80       100                    122          60
# 9          65       80       100                    120          50
# 10         45       60        80                     80          65
# 11          1        1         1                      1           1
# 12      False    False     False                  False       False
#
# ...

# %%
df[(df["Attack"] > 80) & (df["Defense"] > 80)]
# Out:
#        #                       Name  Type 1  Type 2  Total   HP  Attack  \
# 2      3                   Venusaur   Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur   Grass  Poison    625   80     100
# 7      6  CharizardMega Charizard X    Fire  Dragon    634   78     130
# 11     9                  Blastoise   Water     NaN    530   79      83
# 12     9    BlastoiseMega Blastoise   Water     NaN    630   79     103
# ..   ...                        ...     ...     ...    ...  ...     ...
# 793  717                    Yveltal    Dark  Flying    680  126     131
# 794  718           Zygarde50% Forme  Dragon  Ground    600  108     100
# 795  719                    Diancie    Rock   Fairy    600   50     100
# 796  719        DiancieMega Diancie    Rock   Fairy    700   50     160
# 799  721                  Volcanion    Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
e = ["Attack","Defense"]
df[e].head()
# Out:
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3     100      123
# 4      52       43

# %%
s = (df.Attack > 80) | (df.Defense > 80)
df[s]
# Out:
#        #                       Name   Type 1  Type 2  Total  HP  Attack  \
# 2      3                   Venusaur    Grass  Poison    525  80      82
# 3      3      VenusaurMega Venusaur    Grass  Poison    625  80     100
# 6      6                  Charizard     Fire  Flying    534  78      84
# 7      6  CharizardMega Charizard X     Fire  Dragon    634  78     130
# 8      6  CharizardMega Charizard Y     Fire  Flying    634  78     104
# ..   ...                        ...      ...     ...    ...  ..     ...
# 795  719                    Diancie     Rock   Fairy    600  50     100
# 796  719        DiancieMega Diancie     Rock   Fairy    700  50     160
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799  721                  Volcanion     Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df["Type 1"].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df.max()
# Out:
# #                          721
# Name          Zygarde50% Forme
# Type 1                   Water
# Total                      780
# HP                         255
# Attack                     190
# Defense                    230
# Sp. Atk                    194
# Sp. Def                    230
# Speed                      180
# Generation                   6
# Legendary                 True
# dtype: object

# %%
# %matplotlib inline
df.Attack.hist()
